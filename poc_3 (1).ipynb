# %% [markdown]
# **Importing  required libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Importing dataset**

# %%
from google.colab import files
g = files.upload()
# Out:
#      <input type="file" id="files-5f81df93-d09e-4e65-a84c-9e1663b35a4c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5f81df93-d09e-4e65-a84c-9e1663b35a4c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # Reading the csv file

# %%
data = pd.read_csv('Fish poc3 dataset.csv')

# %%
data
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 0     Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1     Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2     Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..      ...     ...      ...      ...      ...      ...     ...
# 154   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 7 columns]

# %% [markdown]
# **shallow copy**

# %%
df = data.copy()

# %%
df
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 0     Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1     Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2     Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..      ...     ...      ...      ...      ...      ...     ...
# 154   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 7 columns]

# %% [markdown]
# to check exploratory data analysis

# %%
df.shape
# Out:
# (159, 7)

# %%
df.columns
# Out:
# Index(['Species', 'Weight', 'Length1', 'Length2', 'Length3', 'Height',
#        'Width'],
#       dtype='object')

# %%
df.head(20)
# Out:
#    Species  Weight  Length1  Length2  Length3   Height   Width
# 0    Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1    Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2    Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3    Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4    Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# 5    Bream   450.0     26.8     29.7     34.7  13.6024  4.9274
# 6    Bream   500.0     26.8     29.7     34.5  14.1795  5.2785
# 7    Bream   390.0     27.6     30.0     35.0  12.6700  4.6900
# 8    Bream   450.0     27.6     30.0     35.1  14.0049  4.8438
# 9    Bream   500.0     28.5     30.7     36.2  14.2266  4.9594
# 10   Bream   475.0     28.4     31.0     36.2  14.2628  5.1042
# 11   Bream   500.0     28.7     31.0     36.2  14.3714  4.8146
# 12   Bream   500.0     29.1     31.5     36.4  13.7592  4.3680
# 13   Bream   340.0     29.5     32.0     37.3  13.9129  5.0728
# ...

# %%
df.tail(15)
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 144    Pike  1650.0     59.0     63.4     68.0  10.8120  7.4800
# 145   Smelt     6.7      9.3      9.8     10.8   1.7388  1.0476
# 146   Smelt     7.5     10.0     10.5     11.6   1.9720  1.1600
# 147   Smelt     7.0     10.1     10.6     11.6   1.7284  1.1484
# 148   Smelt     9.7     10.4     11.0     12.0   2.1960  1.3800
# 149   Smelt     9.8     10.7     11.2     12.4   2.0832  1.2772
# 150   Smelt     8.7     10.8     11.3     12.6   1.9782  1.2852
# 151   Smelt    10.0     11.3     11.8     13.1   2.2139  1.2838
# 152   Smelt     9.9     11.3     11.8     13.1   2.2139  1.1659
# 153   Smelt     9.8     11.4     12.0     13.2   2.2044  1.1484
# 154   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Species  159 non-null    object
#  1   Weight   159 non-null    float64
#  2   Length1  159 non-null    float64
#  3   Length2  159 non-null    float64
#  4   Length3  159 non-null    float64
#  5   Height   159 non-null    float64
#  6   Width    159 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 8.8+ KB

# %%
df.describe()
# Out:
#             Weight     Length1     Length2     Length3      Height       Width
# count   159.000000  159.000000  159.000000  159.000000  159.000000  159.000000
# mean    398.326415   26.247170   28.415723   31.227044    8.970994    4.417486
# std     357.978317    9.996441   10.716328   11.610246    4.286208    1.685804
# min       0.000000    7.500000    8.400000    8.800000    1.728400    1.047600
# 25%     120.000000   19.050000   21.000000   23.150000    5.944800    3.385650
# 50%     273.000000   25.200000   27.300000   29.400000    7.786000    4.248500
# 75%     650.000000   32.700000   35.500000   39.650000   12.365900    5.584500
# max    1650.000000   59.000000   63.400000   68.000000   18.957000    8.142000

# %% [markdown]
# **to clean the data**

# %%
df.isnull().sum()
# Out:
# Species    0
# Weight     0
# Length1    0
# Length2    0
# Length3    0
# Height     0
# Width      0
# dtype: int64

# %%
(df==0).sum()
# Out:
# Species    0
# Weight     1
# Length1    0
# Length2    0
# Length3    0
# Height     0
# Width      0
# dtype: int64

# %% [markdown]
# **Label Encoder**

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['Species'] = le.fit_transform(df['Species'])

# %%
df['Species'].unique()
# Out:
# array([0, 4, 6, 1, 2, 3, 5])

# %% [markdown]
# **Removal of unwanted columns**

# %%
x=df.drop(['Species'],axis=1)
x
# Out:
#      Weight  Length1  Length2  Length3   Height   Width
# 0     242.0     23.2     25.4     30.0  11.5200  4.0200
# 1     290.0     24.0     26.3     31.2  12.4800  4.3056
# 2     340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     430.0     26.5     29.0     34.0  12.4440  5.1340
# ..      ...      ...      ...      ...      ...     ...
# 154    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 6 columns]

# %%
y=df['Species']
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 154    5
# 155    5
# 156    5
# 157    5
# 158    5
# Name: Species, Length: 159, dtype: int64

# %%
corr =df.corr()

# %%
plt.figure(figsize=(5,5))
sns.heatmap(corr,annot=True,cmap='GnBu')
# Out:
# <Axes: >

# %%
data_array = df

# %%
data_array
# Out:
#      Species  Weight  Length1  Length2  Length3   Height   Width
# 0          0   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1          0   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2          0   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3          0   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4          0   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..       ...     ...      ...      ...      ...      ...     ...
# 154        5    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155        5    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156        5    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157        5    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158        5    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 7 columns]

# %% [markdown]
# **Standardization**

# %%
from sklearn.preprocessing import StandardScaler
st_x= StandardScaler()
x_train= st_x.fit_transform(x_train)
x_test= st_x.transform(x_test)

# %% [markdown]
# #Train,Test&Split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.4,random_state=316)

# %% [markdown]
# #Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
L = LogisticRegression()

# %%
L.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# #Predicting the test set result

# %%
y_pred_LO = L.predict(x_test)
y_pred_LO
# Out:
# array([0, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 0, 5, 2, 2, 5, 2, 2, 3, 3, 2,
#        1, 0, 2, 0, 3, 2, 2, 2, 1, 2, 0, 2, 2, 0, 2, 2, 2, 2, 0, 5, 2, 2,
#        2, 2, 2, 3, 5, 2, 2, 2, 2, 2, 3, 2, 0, 2, 5, 2, 2, 0, 0, 3])

# %%
from sklearn.metrics import confusion_matrix,recall_score,accuracy_score,precision_score,f1_score
cm = confusion_matrix(y_test,y_pred,labels=[0,1,2,3,4,5,6])
print('Confusion',cm)
recall = recall_score(y_test,y_pred_LO,average = 'macro')
print('Recall',recall)
accuracy = accuracy_score(y_test,y_pred_LO)
print('Accuracy',accuracy)
precision = precision_score(y_test,y_pred_LO,average = 'macro',zero_division = 1)
print('Precision',precision)
F1score = f1_score(y_test,y_pred_LO,average = 'macro')
print('F1 score',F1score)
# Out:
# Confusion [[10  0  0  0  0  0  0]
#  [ 1  3  0  0  0  0  0]
#  [ 0  0 20  0  0  0  0]
#  [ 0  0  0  7  0  0  0]
#  [ 0  0 13  0  0  0  0]
#  [ 0  0  2  0  0  5  0]
#  [ 0  0  3  0  0  0  0]]
# Recall 0.6173469387755102
# Accuracy 0.6875
# Precision 0.9174159174159174
# F1 score 0.6062714525184258

# %%
x_train
# Out:
# array([[-1.12161923, -1.59365837, -1.63910535, -1.66186988, -1.67881458,
#         -1.9134474 ],
#        [ 1.28301112,  1.01648341,  1.01117799,  1.14102441,  1.79703303,
#          0.98946105],
#        [ 0.39004494,  0.21479701,  0.22912717,  0.39412134,  1.2042857 ,
#          0.3210762 ],
#        [-0.80908107, -0.66146488, -0.63981819, -0.70615521, -0.75985746,
#         -0.59584286],
#        [ 1.4488477 ,  0.92326406,  0.92428346,  0.81174456,  0.63274678,
#          1.59778765],
#        [ 1.41057772,  0.59699634,  0.66359985,  0.82780699,  2.09317352,
#          1.118993  ],
#        [ 1.15544452,  0.92326406,  0.92428346,  0.81977578,  0.48821868,
#          1.46552578],
#        [-0.27330136, -0.29790941, -0.24879278, -0.09578282,  0.63208055,
#          0.05660817],
#        [ 1.41057772,  1.30546339,  1.2718616 ,  1.14905562,  0.65673116,
#          1.67210834],
#        [-0.82183773, -0.75468422, -0.72671272, -0.78646737, -0.85257486,
#         -0.51645231],
# ...

# %%
y_train
# Out:
# 146    5
# 34     0
# 14     0
# 88     2
# 121    2
#       ..
# 152    5
# 96     2
# 87     2
# 62     1
# 61     1
# Name: Species, Length: 95, dtype: int64

# %% [markdown]
# #K-Neighbors Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier= KNeighborsClassifier(n_neighbors=5,p=2 )
classifier.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# #Predicting the test set result

# %%
y_pred_KNN = classifier.predict(x_test)
y_pred_KNN
# Out:
# array([0, 0, 2, 2, 2, 2, 2, 2, 2, 2, 3, 1, 0, 5, 2, 2, 5, 2, 2, 3, 3, 2,
#        1, 0, 2, 0, 3, 2, 2, 2, 1, 2, 0, 2, 2, 0, 2, 2, 2, 2, 0, 5, 2, 2,
#        2, 2, 2, 3, 5, 2, 2, 2, 2, 2, 3, 2, 0, 2, 5, 2, 2, 0, 0, 3])

# %%
from sklearn.metrics import confusion_matrix,recall_score,accuracy_score,precision_score,f1_score
cm = confusion_matrix(y_test,y_pred_KNN,labels=[0,1,2,3,4,5,6])
print('Confusion',cm)
recall = recall_score(y_test,y_pred_KNN,average = 'macro')
print('Recall',recall)
accuracy = accuracy_score(y_test,y_pred_KNN)
print('Accuracy',accuracy)
precision = precision_score(y_test,y_pred_KNN,average = 'macro',zero_division = 1)
print('Precision',precision)
F1score = f1_score(y_test,y_pred_KNN,average = 'macro')
print('F1 score',F1score)
# Out:
# Confusion [[10  0  0  0  0  0  0]
#  [ 1  3  0  0  0  0  0]
#  [ 0  0 20  0  0  0  0]
#  [ 0  0  0  7  0  0  0]
#  [ 0  0 13  0  0  0  0]
#  [ 0  0  2  0  0  5  0]
#  [ 0  0  3  0  0  0  0]]
# Recall 0.6377551020408163
# Accuracy 0.703125
# Precision 0.9193438140806561
# F1 score 0.6189303307529909

# %% [markdown]
# #Predicting the test set result

# %%
y_pred= classifier.predict(x_test)
y_pred
# Out:
# array([0, 0, 2, 2, 2, 2, 2, 2, 2, 2, 3, 1, 0, 5, 2, 2, 5, 2, 2, 3, 3, 2,
#        1, 0, 2, 0, 3, 2, 2, 2, 1, 2, 0, 2, 2, 0, 2, 2, 2, 2, 0, 5, 2, 2,
#        2, 2, 2, 3, 5, 2, 2, 2, 2, 2, 3, 2, 0, 2, 5, 2, 2, 0, 0, 3])

# %% [markdown]
# # support vector machine

# %%
from sklearn.svm import SVC
classifier2 = SVC(kernel = 'linear', random_state = 0)
classifier2.fit(x_train, y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %%
y_pred_SVC= classifier2.predict(x_test)
y_pred_SVC
# Out:
# array([0, 0, 2, 2, 2, 2, 2, 2, 2, 2, 3, 1, 0, 5, 2, 2, 5, 2, 2, 3, 3, 2,
#        1, 0, 2, 0, 3, 2, 2, 2, 1, 2, 0, 2, 2, 0, 2, 2, 2, 2, 0, 5, 2, 2,
#        5, 2, 2, 3, 5, 2, 2, 2, 2, 2, 3, 2, 0, 2, 5, 2, 5, 0, 0, 3])

# %%
from sklearn.metrics import confusion_matrix,recall_score,accuracy_score,precision_score,f1_score
cm = confusion_matrix(y_test,y_pred_SVC,labels=[0,1,2,3,4,5,6])
print('Confusion',cm)
recall = recall_score(y_test,y_pred_SVC,average = 'macro')
print('Recall',recall)
accuracy = accuracy_score(y_test,y_pred_SVC)
print('Accuracy',accuracy)
precision = precision_score(y_test,y_pred_SVC,average = 'macro',zero_division = 1)
print('Precision',precision)
F1score = f1_score(y_test,y_pred_SVC,average = 'macro')
print('F1 score',F1score)
# Out:
# Confusion [[10  0  0  0  0  0  0]
#  [ 1  3  0  0  0  0  0]
#  [ 0  0 20  0  0  0  0]
#  [ 0  0  0  7  0  0  0]
#  [ 0  0 13  0  0  0  0]
#  [ 0  0  0  0  0  7  0]
#  [ 0  0  3  0  0  0  0]]
# Recall 0.6785714285714286
# Accuracy 0.734375
# Precision 0.9235209235209235
# F1 score 0.6462585034013605

# %% [markdown]
# #Creating the Confusion matrix

# %%
from sklearn.metrics import confusion_matrix
cm= confusion_matrix(y_test, y_pred)

# %%
cm
# Out:
# array([[10,  0,  0,  0,  0,  0,  0],
#        [ 1,  3,  0,  0,  0,  0,  0],
#        [ 0,  0, 20,  0,  0,  0,  0],
#        [ 0,  0,  0,  7,  0,  0,  0],
#        [ 0,  0, 13,  0,  0,  0,  0],
#        [ 0,  0,  2,  0,  0,  5,  0],
#        [ 0,  0,  3,  0,  0,  0,  0]])

# %% [markdown]
# **Evaluation Metrics**

# %%
from sklearn.metrics import confusion_matrix,recall_score,accuracy_score,precision_score,f1_score
cm = confusion_matrix(y_test,y_pred,labels=[0,1,2,3,4,5,6])
print('Confusion',cm)
recall = recall_score(y_test,y_pred,average = 'macro')
print('Recall',recall)
accuracy = accuracy_score(y_test,y_pred)
print('Accuracy',accuracy)
precision = precision_score(y_test,y_pred,average = 'macro',zero_division = 1)
print('Precision',precision)
F1score = f1_score(y_test,y_pred,average = 'macro')
print('F1 score',F1score)
# Out:
# Confusion [[10  0  0  0  0  0  0]
#  [ 1  3  0  0  0  0  0]
#  [ 0  0 20  0  0  0  0]
#  [ 0  0  0  7  0  0  0]
#  [ 0  0 13  0  0  0  0]
#  [ 0  0  2  0  0  5  0]
#  [ 0  0  3  0  0  0  0]]
# Recall 0.6377551020408163
# Accuracy 0.703125
# Precision 0.9193438140806561
# F1 score 0.6189303307529909
